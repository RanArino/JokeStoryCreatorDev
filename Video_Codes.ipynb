# %%
#from moviepy.editor import ipython_display
import Functions as F
import importlib

# %%
importlib.reload(F)
# Out:
# <module 'Functions' from 'c:\\Users\\runru\\MyGPTs\\MyGPTs-Dev-Mode\\JokeStoryCreator\\Developer\\Functions.py'>

# %%
num = [i for i in range(1055, 1060)]
num
# Out:
# [1055, 1056, 1057, 1058, 1059]

# %%
confirm = input("Did you check the four-panel image accurately, if so answer 'Yes'.")
# Normal
if confirm == 'Yes':
    video = F.Video(path='joke_data2.json')
    video.generate_video(id_list=num, t_interval = 60, crop_mode='auto')  # manual or auto
# Out:
# Moviepy - Building video Videos/1055_RoboRage.mp4.
# MoviePy - Writing audio in 1055_RoboRageTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video Videos/1055_RoboRage.mp4
# Moviepy - Done !
# Moviepy - video ready Videos/1055_RoboRage.mp4
# Moviepy - Building video Videos/1056_FastCity.mp4.
# MoviePy - Writing audio in 1056_FastCityTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video Videos/1056_FastCity.mp4
# Moviepy - Done !
# Moviepy - video ready Videos/1056_FastCity.mp4
# Moviepy - Building video Videos/1057_JuvenileJudgment.mp4.
# MoviePy - Writing audio in 1057_JuvenileJudgmentTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video Videos/1057_JuvenileJudgment.mp4
# Moviepy - Done !
# Moviepy - video ready Videos/1057_JuvenileJudgment.mp4
# Moviepy - Building video Videos/1058_SlitheryBuilder.mp4.
# MoviePy - Writing audio in 1058_SlitheryBuilderTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video Videos/1058_SlitheryBuilder.mp4
# Moviepy - Done !
# Moviepy - video ready Videos/1058_SlitheryBuilder.mp4
# Moviepy - Building video Videos/1059_CarelessQuery.mp4.
# MoviePy - Writing audio in 1059_CarelessQueryTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video Videos/1059_CarelessQuery.mp4
# Moviepy - Done !
# Moviepy - video ready Videos/1059_CarelessQuery.mp4

# %%
import matplotlib.pyplot as plt
import os
import cv2
importlib.reload(F)
video = F.Video()

img_path = [f"Images/{p}" for p in os.listdir('Images') if len(p.split('_')[0]) == 4]

# %%
for path in img_path[-5:]:
    cropped = video.auto_crop_comic_strip(path, mode='auto')  # 'auto' or 'manual'
    
    # Create a figure that can accommodate both the layouts of fig1 and fig2
    fig3, axs = plt.subplots(2, 3, figsize=(8, 5))  # Creating a 2x3 grid overall
    fig3.suptitle(path)

    # The first four subplots (2x2) at indices 0, 1, 3, 4 of a 2x3 grid
    for i in range(4):
        ax = axs[i // 2, i % 2]  # Positioning subplots in a 2x2 configuration within the 2x3 grid
        ax.imshow(cropped[i])
        ax.set_xticks([])
        ax.set_yticks([])

    # The last two subplots (1x2) at indices 2 and 5 of a 2x3 grid
    # Assuming only two images are processed for the important part, you can adjust this as necessary
    for j in [2, 5]:
        ax = axs[j // 3, j % 3]  # Positioning in the top right and bottom right
        ax.imshow(video.crop_important_part_to_scale(cropped[j-2]))  # Assuming these indices for important parts
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
#ipython_display(comp, width=360, height=640, fps=1)

# %%
"""
# Valentine Specials
from moviepy.editor import VideoFileClip, ImageClip
importlib.reload(F)

video = F.Video()

specials = {'title': [
    ImageClip('Specials/valentine_title01.png').set_opacity(0.5),    # title
    VideoFileClip('Specials/valentine_title02.mp4').set_opacity(0.3) # animation
]}

video.generate_video(id_list=num, specials=specials)
"""

# %% [markdown]
# ### Image resolution

# %%
# create high resolution images
import os
import time
video = F.Video()

# after resolution
#high_img_paths = os.listdir("Landscapes")
# original
#img_paths = os.listdir("Titles_Ends")[len(high_img_paths):]

# define id (resoluting image whose id is >= id_after)
id_after = 51
img_paths = [path for path in os.listdir("Titles_Ends") if int(path.split('_')[0]) >= id_after]

for path in img_paths:
    _ = video.image_resolution(img_data=f"Titles_Ends/{path}", target_size=(3600, 6400), img_save=True, new_img_path=f'../../ViewVistas/Landscapes/{path}')
    time.sleep(90)

# %%
import cv2
test = cv2.imread('Images/081_SweetCompromise.png')
# Out:
# (2560, 2560, 3)

# %% [markdown]
# ### Memo

# %%
# test
#ipython_display(clips[1], fps=1, width=360, height=640)

# %%
"""import os
def delete_audio_files():
    for file in os.listdir("Audios"):
        os.remove(f"Audios/{file}")"""
